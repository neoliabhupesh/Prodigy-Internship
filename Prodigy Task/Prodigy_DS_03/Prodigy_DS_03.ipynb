# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('bank.csv')

# %%
df.rename(columns={'y':'Deposit'},inplace=True)
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome Deposit
# 0  cellular   19   oct        79         1     -1         0  unknown      no
# 1  cellular   11   may       220         1    339         4  failure      no
# 2  cellular   16   apr       185         1    330         1  failure      no
# 3   unknown    3   jun       199         4     -1         0  unknown      no
# 4   unknown    5   may       226         1     -1         0  unknown      no

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  Deposit    4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 4516  cellular   30   jul       329         5     -1         0  unknown
# 4517   unknown    9   may       153         1     -1         0  unknown
# 4518  cellular   19   aug       151        11     -1         0  unknown
# 4519  cellular    6   feb       129         4    211         3    other
# 4520  cellular    3   apr       345         2    249         7    other
#
#      Deposit
# 4516      no
# 4517      no
# 4518      no
# 4519      no
# 4520      no

# %%
df.age
# Out:
# 0       30
# 1       33
# 2       35
# 3       30
# 4       59
#         ..
# 4516    33
# 4517    57
# 4518    57
# 4519    28
# 4520    44
# Name: age, Length: 4521, dtype: int64

# %%
sns.boxplot(df.age)
# Out:
# <Axes: >

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# Deposit      object
# dtype: object

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
df['Deposit'].value_counts()
# Out:
# Deposit
# no     4000
# yes     521
# Name: count, dtype: int64

# %%
df['Deposit'].value_counts()/df.shape[0]
# Out:
# Deposit
# no     0.88476
# yes    0.11524
# Name: count, dtype: float64

# %%
df.shape[0]
# Out:
# 4521

# %% [markdown]
# ### EDA and Visualisation

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.countplot(x='Deposit', data=df)
plt.title("Categories of Yes and No", size = 10)

plt.subplot(1, 2, 2)
labels = df['Deposit'].value_counts(sort=True).index
sizes = df['Deposit'].value_counts(sort =True)
plt.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=230,)
plt.title("Total Yes and No category", size = 10)
sizes
#plt.show()
# Out:
# Deposit
# no     4000
# yes     521
# Name: count, dtype: int64

# %% [markdown]
# ### Data Visualization and Data Cleaning

# %%
df_num = df[['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous','Deposit']]
col = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous','Deposit']
plt.figure(figsize=(15,18))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(4,2,i+1)
    sns.scatterplot(x=v,y='Deposit' ,data=df_num,color='blue')
    plt.title("scatterplot of {}  by deposit".format(v),size=20,color="red")
    plt.xlabel("{}".format(v),size=15)
    plt.ylabel("Deposit",size=15)
plt.tight_layout()
plt.show()
# Out:
# 0 age
# 1 balance
# 2 day
# 3 duration
# 4 campaign
# 5 pdays
# 6 previous
# 7 Deposit

# %%
df_num = df[['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']]
col = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
plt.figure(figsize=(15,18))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(4,2,i+1)
    sns.boxplot(x=v,data=df_num,color='green')
    plt.title("Boxplot of {}".format(v),size=20,color="red")
    plt.xlabel("{}".format(v),size=15)
plt.tight_layout()
plt.show()
# Out:
# 0 age
# 1 balance
# 2 day
# 3 duration
# 4 campaign
# 5 pdays
# 6 previous

# %% [markdown]
# ### Correlation Heatmap

# %%
#Pearson’s Correlations, which measures the strength of a linear relationship
df_num = df[['age', 'balance', 'day', 'duration', 'campaign', 'previous']]
plt.figure(figsize=(10,7))
sns.heatmap(data=df_num.corr(), annot=True)
plt.show()

# %% [markdown]
# ### Handling Outliers

# %%
len(df[df['balance']<0])/len(df)
# Out:
# 0.0809555408095554

# %%
df[(df['balance']>40000)|(df['balance']<0)]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 9      43       services   married    primary      no      -88     yes  yes
# 18     25    blue-collar    single    primary      no     -221     yes   no
# 48     32   entrepreneur    single    primary     yes     -849     yes  yes
# 60     41    blue-collar   married    primary      no     -516      no  yes
# 92     27       services    single  secondary      no     -195     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4474   44    blue-collar   married    primary      no     -237     yes   no
# 4502   42       services   married  secondary      no      -91     yes  yes
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4516   33       services   married  secondary      no     -333     yes   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 9      cellular   17   apr       313         1    147         2  failure
# 18      unknown   23   may       250         1     -1         0  unknown
# 48     cellular    4   feb       204         1     -1         0  unknown
# 60    telephone    8   jul       554         3     -1         0  unknown
# 92     cellular   18   may       391         1     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 4474  telephone   10   jul        73         1     -1         0  unknown
# 4502   cellular    5   feb        43         1     -1         0  unknown
# 4506   cellular   29   aug        85         4     -1         0  unknown
# 4516   cellular   30   jul       329         5     -1         0  unknown
# 4517    unknown    9   may       153         1     -1         0  unknown
#
#      Deposit
# 9         no
# 18        no
# 48        no
# 60        no
# 92       yes
# ...      ...
# 4474      no
# 4502      no
# 4506      no
# 4516      no
# 4517      no
#
# [368 rows x 17 columns]

# %%
df.drop(df[(df['balance']>40000)|(df['balance']<0)].index,inplace=True,axis=0)

# %%
df[df['duration']>3000]
# Out:
#      age         job  marital education default  balance housing loan  \
# 568   59  unemployed  married   primary      no        0      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome Deposit
# 568  cellular   30   jan      3025         2     -1         0  unknown      no

# %%
df[df['campaign']>40]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 2504   35  blue-collar  married  secondary      no      280     yes  yes
# 4301   49  blue-collar  married    primary      no      371     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 2504  cellular   31   jul        65        50     -1         0  unknown
# 4301  cellular   31   jul        18        44     -1         0  unknown
#
#      Deposit
# 2504      no
# 4301      no

# %%
df.drop(df[df['campaign']>30].index,axis=0,inplace=True)

# %%
df.drop(df[df['duration']>3000].index,inplace=True,axis=0)

# %%
df[df['pdays']==-1]
# Out:
#       age           job  marital  education default  balance housing loan  \
# 0      30    unemployed  married    primary      no     1787      no   no
# 3      30    management  married   tertiary      no     1476     yes  yes
# 4      59   blue-collar  married  secondary      no        0     yes   no
# 7      39    technician  married  secondary      no      147     yes   no
# 8      41  entrepreneur  married   tertiary      no      221     yes   no
# ...   ...           ...      ...        ...     ...      ...     ...  ...
# 4511   46   blue-collar  married  secondary      no      668     yes   no
# 4512   40   blue-collar  married  secondary      no     1100     yes   no
# 4513   49   blue-collar  married  secondary      no      322      no   no
# 4515   32      services   single  secondary      no      473     yes   no
# 4518   57    technician  married  secondary      no      295      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 0     cellular   19   oct        79         1     -1         0  unknown
# 3      unknown    3   jun       199         4     -1         0  unknown
# 4      unknown    5   may       226         1     -1         0  unknown
# 7     cellular    6   may       151         2     -1         0  unknown
# 8      unknown   14   may        57         2     -1         0  unknown
# ...        ...  ...   ...       ...       ...    ...       ...      ...
# 4511   unknown   15   may      1263         2     -1         0  unknown
# 4512   unknown   29   may       660         2     -1         0  unknown
# 4513  cellular   14   aug       356         2     -1         0  unknown
# 4515  cellular    7   jul       624         5     -1         0  unknown
# 4518  cellular   19   aug       151        11     -1         0  unknown
#
#      Deposit
# 0         no
# 3         no
# 4         no
# 7         no
# 8         no
# ...      ...
# 4511     yes
# 4512      no
# 4513      no
# 4515      no
# 4518      no
#
# [3374 rows x 17 columns]

# %%
df[df['poutcome']=='unknown']
# Out:
#       age           job  marital  education default  balance housing loan  \
# 0      30    unemployed  married    primary      no     1787      no   no
# 3      30    management  married   tertiary      no     1476     yes  yes
# 4      59   blue-collar  married  secondary      no        0     yes   no
# 7      39    technician  married  secondary      no      147     yes   no
# 8      41  entrepreneur  married   tertiary      no      221     yes   no
# ...   ...           ...      ...        ...     ...      ...     ...  ...
# 4511   46   blue-collar  married  secondary      no      668     yes   no
# 4512   40   blue-collar  married  secondary      no     1100     yes   no
# 4513   49   blue-collar  married  secondary      no      322      no   no
# 4515   32      services   single  secondary      no      473     yes   no
# 4518   57    technician  married  secondary      no      295      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 0     cellular   19   oct        79         1     -1         0  unknown
# 3      unknown    3   jun       199         4     -1         0  unknown
# 4      unknown    5   may       226         1     -1         0  unknown
# 7     cellular    6   may       151         2     -1         0  unknown
# 8      unknown   14   may        57         2     -1         0  unknown
# ...        ...  ...   ...       ...       ...    ...       ...      ...
# 4511   unknown   15   may      1263         2     -1         0  unknown
# 4512   unknown   29   may       660         2     -1         0  unknown
# 4513  cellular   14   aug       356         2     -1         0  unknown
# 4515  cellular    7   jul       624         5     -1         0  unknown
# 4518  cellular   19   aug       151        11     -1         0  unknown
#
#      Deposit
# 0         no
# 3         no
# 4         no
# 7         no
# 8         no
# ...      ...
# 4511     yes
# 4512      no
# 4513      no
# 4515      no
# 4518      no
#
# [3374 rows x 17 columns]

# %%
df[df['previous']==0]
# Out:
#       age           job  marital  education default  balance housing loan  \
# 0      30    unemployed  married    primary      no     1787      no   no
# 3      30    management  married   tertiary      no     1476     yes  yes
# 4      59   blue-collar  married  secondary      no        0     yes   no
# 7      39    technician  married  secondary      no      147     yes   no
# 8      41  entrepreneur  married   tertiary      no      221     yes   no
# ...   ...           ...      ...        ...     ...      ...     ...  ...
# 4511   46   blue-collar  married  secondary      no      668     yes   no
# 4512   40   blue-collar  married  secondary      no     1100     yes   no
# 4513   49   blue-collar  married  secondary      no      322      no   no
# 4515   32      services   single  secondary      no      473     yes   no
# 4518   57    technician  married  secondary      no      295      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome  \
# 0     cellular   19   oct        79         1     -1         0  unknown
# 3      unknown    3   jun       199         4     -1         0  unknown
# 4      unknown    5   may       226         1     -1         0  unknown
# 7     cellular    6   may       151         2     -1         0  unknown
# 8      unknown   14   may        57         2     -1         0  unknown
# ...        ...  ...   ...       ...       ...    ...       ...      ...
# 4511   unknown   15   may      1263         2     -1         0  unknown
# 4512   unknown   29   may       660         2     -1         0  unknown
# 4513  cellular   14   aug       356         2     -1         0  unknown
# 4515  cellular    7   jul       624         5     -1         0  unknown
# 4518  cellular   19   aug       151        11     -1         0  unknown
#
#      Deposit
# 0         no
# 3         no
# 4         no
# 7         no
# 8         no
# ...      ...
# 4511     yes
# 4512      no
# 4513      no
# 4515      no
# 4518      no
#
# [3374 rows x 17 columns]

# %%
df.drop("pdays",inplace=True,axis=1)

# %%
df[df['previous']>30]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, previous, poutcome, Deposit]
# Index: []

# %%
df.drop(df[df['previous']>30].index,axis=0,inplace=True)

# %%
plt.hist(x="campaign",data=df,color='green')
plt.show()

# %%
df1 = df.copy()

# %% [markdown]
# Duration is matter most clearly seen from above plot higher the duration more the chances that person will subscrised for deposit
# Campaign should be low as possible
# pdays should be more
# People those susbcribed for deposit has higher balance

# %% [markdown]
# ## Correlation Heatmap

# %%
df_num = df[['age', 'balance', 'day', 'duration', 'campaign', 'previous']]
plt.figure(figsize=(10,7))
sns.heatmap(data=df_num.corr(), annot=True)
plt.show()

# %%
dic = {"yes":1,"no":0}

# %%
from sklearn.preprocessing import LabelEncoder
dic = {"yes":1,"no":0}
lst = ["Deposit","loan","default","housing"]
for i in lst:
    df[i] = df[i].map(dic)

# %%
l=['month',"contact","poutcome"]
for i in l:
    le=LabelEncoder()
    df[i]=le.fit_transform(df[i].values)

# %%
df = pd.get_dummies(df, columns = ['job','marital','education'])

# %%
df
# Out:
#       age  default  balance  housing  loan  contact  day  month  duration  \
# 0      30        0     1787        0     0        0   19     10        79
# 1      33        0     4789        1     1        0   11      8       220
# 2      35        0     1350        1     0        0   16      0       185
# 3      30        0     1476        1     1        2    3      6       199
# 4      59        0        0        1     0        2    5      8       226
# ...   ...      ...      ...      ...   ...      ...  ...    ...       ...
# 4514   38        0     1205        1     0        0   20      0        45
# 4515   32        0      473        1     0        0    7      5       624
# 4518   57        0      295        0     0        0   19      1       151
# 4519   28        0     1137        0     0        0    6      3       129
# 4520   44        0     1136        1     1        0    3      0       345
#
#       campaign  ...  job_technician  job_unemployed  job_unknown  \
# 0            1  ...           False            True        False
# 1            1  ...           False           False        False
# 2            1  ...           False           False        False
# 3            4  ...           False           False        False
# 4            1  ...           False           False        False
# ...        ...  ...             ...             ...          ...
# 4514         4  ...           False           False        False
# 4515         5  ...           False           False        False
# 4518        11  ...            True           False        False
# 4519         4  ...           False           False        False
# 4520         2  ...           False           False        False
#
#       marital_divorced  marital_married  marital_single  education_primary  \
# 0                False             True           False               True
# 1                False             True           False              False
# 2                False            False            True              False
# 3                False             True           False              False
# 4                False             True           False              False
# ...                ...              ...             ...                ...
# 4514             False             True           False              False
# 4515             False            False            True              False
# 4518             False             True           False              False
# 4519             False             True           False              False
# 4520             False            False            True              False
#
#       education_secondary  education_tertiary  education_unknown
# 0                   False               False              False
# 1                    True               False              False
# 2                   False                True              False
# 3                   False                True              False
# 4                    True               False              False
# ...                   ...                 ...                ...
# 4514                 True               False              False
# 4515                 True               False              False
# 4518                 True               False              False
# 4519                 True               False              False
# 4520                False                True              False
#
# [4147 rows x 32 columns]

# %%
df=df.reset_index()

# %%
df.drop('index',axis=1,inplace=True)

# %%
df
# Out:
#       age  default  balance  housing  loan  contact  day  month  duration  \
# 0      30        0     1787        0     0        0   19     10        79
# 1      33        0     4789        1     1        0   11      8       220
# 2      35        0     1350        1     0        0   16      0       185
# 3      30        0     1476        1     1        2    3      6       199
# 4      59        0        0        1     0        2    5      8       226
# ...   ...      ...      ...      ...   ...      ...  ...    ...       ...
# 4142   38        0     1205        1     0        0   20      0        45
# 4143   32        0      473        1     0        0    7      5       624
# 4144   57        0      295        0     0        0   19      1       151
# 4145   28        0     1137        0     0        0    6      3       129
# 4146   44        0     1136        1     1        0    3      0       345
#
#       campaign  ...  job_technician  job_unemployed  job_unknown  \
# 0            1  ...           False            True        False
# 1            1  ...           False           False        False
# 2            1  ...           False           False        False
# 3            4  ...           False           False        False
# 4            1  ...           False           False        False
# ...        ...  ...             ...             ...          ...
# 4142         4  ...           False           False        False
# 4143         5  ...           False           False        False
# 4144        11  ...            True           False        False
# 4145         4  ...           False           False        False
# 4146         2  ...           False           False        False
#
#       marital_divorced  marital_married  marital_single  education_primary  \
# 0                False             True           False               True
# 1                False             True           False              False
# 2                False            False            True              False
# 3                False             True           False              False
# 4                False             True           False              False
# ...                ...              ...             ...                ...
# 4142             False             True           False              False
# 4143             False            False            True              False
# 4144             False             True           False              False
# 4145             False             True           False              False
# 4146             False            False            True              False
#
#       education_secondary  education_tertiary  education_unknown
# 0                   False               False              False
# 1                    True               False              False
# 2                   False                True              False
# 3                   False                True              False
# 4                    True               False              False
# ...                   ...                 ...                ...
# 4142                 True               False              False
# 4143                 True               False              False
# 4144                 True               False              False
# 4145                 True               False              False
# 4146                False                True              False
#
# [4147 rows x 32 columns]

# %%
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
X = df.drop('Deposit',axis=1)
Y = df['Deposit']

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4142    0
# 4143    0
# 4144    0
# 4145    0
# 4146    0
# Name: Deposit, Length: 4147, dtype: int64

# %%
sss = StratifiedShuffleSplit(n_splits=1,test_size=0.3,random_state=1)
for train_index,test_index in sss.split(X,Y):
    train_df = df.loc[train_index]
    test_df = df.loc[test_index]

# %%
print("Ratio for train dataset")
print(train_df['Deposit'].value_counts()/train_df.shape[0])
print()
print("ratio for test dataset")
print(test_df['Deposit'].value_counts()/test_df.shape[0])
# Out:
# Ratio for train dataset
# Deposit
# 0    0.881806
# 1    0.118194
# Name: count, dtype: float64
#
# ratio for test dataset
# Deposit
# 0    0.881928
# 1    0.118072
# Name: count, dtype: float64

# %% [markdown]
# ### Train and Test dataset

# %%
X_train = train_df.drop("Deposit",axis=1)
Y_train = train_df['Deposit']

X_test = test_df.drop("Deposit",axis=1)
Y_test = test_df['Deposit']

# %%
X_train
# Out:
#       age  default  balance  housing  loan  contact  day  month  duration  \
# 2370   46        0      295        1     0        2   23      8       141
# 2743   45        0      644        0     1        1   22      5        92
# 2495   34        0     8309        1     1        0   19      9        50
# 327    29        0      318        1     0        0   18      8      1434
# 2005   23        0        4        1     0        2   13      8       395
# ...   ...      ...      ...      ...   ...      ...  ...    ...       ...
# 806    37        0    11303        0     0        0   26      8       500
# 2959   39        0     3797        0     0        0    2      6        96
# 2435   36        0      428        0     0        2   28      8       121
# 3842   52        0        0        0     0        0    9      1       145
# 2707   32        0     1787        1     0        0   12      8        87
#
#       campaign  ...  job_technician  job_unemployed  job_unknown  \
# 2370         6  ...           False           False        False
# 2743         1  ...           False           False        False
# 2495         1  ...           False           False        False
# 327          2  ...           False           False        False
# 2005         2  ...           False           False        False
# ...        ...  ...             ...             ...          ...
# 806          2  ...           False           False        False
# 2959         2  ...           False           False        False
# 2435         1  ...           False           False        False
# 3842         3  ...            True           False        False
# 2707         4  ...           False           False        False
#
#       marital_divorced  marital_married  marital_single  education_primary  \
# 2370             False            False            True              False
# 2743             False             True           False              False
# 2495             False             True           False              False
# 327              False             True           False              False
# 2005             False            False            True               True
# ...                ...              ...             ...                ...
# 806              False             True           False              False
# 2959             False            False            True              False
# 2435             False             True           False              False
# 3842             False             True           False              False
# 2707             False             True           False              False
#
#       education_secondary  education_tertiary  education_unknown
# 2370                 True               False              False
# 2743                 True               False              False
# 2495                 True               False              False
# 327                 False                True              False
# 2005                False               False              False
# ...                   ...                 ...                ...
# 806                  True               False              False
# 2959                False                True              False
# 2435                False                True              False
# 3842                False                True              False
# 2707                 True               False              False
#
# [2902 rows x 31 columns]

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_s = ss.fit_transform(X_train)
X_test_s = ss.transform(X_test)

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Logistic Regression

# %%
lr= LogisticRegression()

lr.fit(X_train_s,Y_train)
Y_pred_lr = lr.predict(X_test_s)

print("Testing Accuracy of LogisticRegression : ",metrics.accuracy_score(Y_test,Y_pred_lr))
#print("Accuracy of LogisticRegression",pipe_lr.score(X_test,Y_test))

print("Training Accuracy of LogisticRegression : ",lr.score(X_train_s,Y_train))
# Out:
# Testing Accuracy of LogisticRegression :  0.8883534136546185
# Training Accuracy of LogisticRegression :  0.8900758097863543

# %% [markdown]
# SVM (Suport Vector Machine)

# %%
svm=svm.SVC(kernel='linear')

svm.fit(X_train_s,Y_train)
Y_pred_svm = svm.predict(X_test_s)

print("Testing Accuracy of SVM : ",metrics.accuracy_score(Y_test,Y_pred_svm))
#print("Accuracy of LogisticRegression",pipe_lr.score(X_test,Y_test))

print("Training Accuracy of SVM : ",svm.score(X_train_s,Y_train))
# Out:
# Testing Accuracy of SVM :  0.8819277108433735
# Training Accuracy of SVM :  0.8818056512749828

# %%
l = list(range(1,25,2))
for i in l:
    knn1= KNeighborsClassifier(n_neighbors=i)
    knn1.fit(X_train_s,Y_train)
    Y_pred = knn1.predict(X_test_s)
    accuracy = metrics.accuracy_score(Y_test,Y_pred)
    train_acc = knn1.score(X_train_s,Y_train)
    print(f"For K={i} test accuracy score is {accuracy} :".format(i,accuracy))
    print(f"For K={i} train accuracy score is {accuracy} :".format(i,train_acc))
    print()
# Out:
# For K=1 test accuracy score is 0.8538152610441767 :
# For K=1 train accuracy score is 0.8538152610441767 :
#
# For K=3 test accuracy score is 0.8746987951807229 :
# For K=3 train accuracy score is 0.8746987951807229 :
#
# For K=5 test accuracy score is 0.8883534136546185 :
# For K=5 train accuracy score is 0.8883534136546185 :
#
# For K=7 test accuracy score is 0.8811244979919679 :
# For K=7 train accuracy score is 0.8811244979919679 :
#
# For K=9 test accuracy score is 0.885140562248996 :
# For K=9 train accuracy score is 0.885140562248996 :
#
# For K=11 test accuracy score is 0.885140562248996 :
# For K=11 train accuracy score is 0.885140562248996 :
#
# For K=13 test accuracy score is 0.8843373493975903 :
# For K=13 train accuracy score is 0.8843373493975903 :
#
# For K=15 test accuracy score is 0.8859437751004016 :
# For K=15 train accuracy score is 0.8859437751004016 :
#
# For K=17 test accuracy score is 0.885140562248996 :
# For K=17 train accuracy score is 0.885140562248996 :
#
# For K=19 test accuracy score is 0.8859437751004016 :
# For K=19 train accuracy score is 0.8859437751004016 :
#
# For K=21 test accuracy score is 0.885140562248996 :
# For K=21 train accuracy score is 0.885140562248996 :
#
# For K=23 test accuracy score is 0.885140562248996 :
# For K=23 train accuracy score is 0.885140562248996 :

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state=5)

gb.fit(X_train_s,Y_train.squeeze().values)
y_train_preds = gb.predict(X_train_s)
y_test_preds = gb.predict(X_test_s)

print('The accuracy of the GB is',metrics.accuracy_score(Y_test,y_test_preds))
print('The accuracy of the GB is',metrics.accuracy_score(y_train_preds,Y_train))
# Out:
# The accuracy of the GB is 0.8947791164658635
# The accuracy of the GB is 0.9317711922811854

# %%
print(classification_report(Y_test,y_test_preds))
print(confusion_matrix(Y_test,y_test_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      1098
#            1       0.60      0.33      0.43       147
#
#     accuracy                           0.89      1245
#    macro avg       0.76      0.65      0.69      1245
# weighted avg       0.88      0.89      0.88      1245
#
# [[1065   33]
#  [  98   49]]

# %%
plt.figure(figsize=(7,5))
sns.heatmap(confusion_matrix(Y_test,y_test_preds),annot=True,cmap="OrRd_r",
            fmt="d",cbar=True,xticklabels=['Yes','No'],yticklabels=['Yes','No'],
            annot_kws={"fontsize":15})
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(confusion_matrix(Y_test,y_test_preds),annot=True,cmap="OrRd_r",
            fmt="d",cbar=True,xticklabels=['Yes','No'],yticklabels=['Yes','No'],
            annot_kws={"fontsize":15})
plt.show()

# %%
df3 = pd.DataFrame()
df3['balance']=df['balance']

df3['deposit']=df['Deposit']
df3['balance_quantile'] = pd.qcut(df3['balance'], q=25, labels=False, duplicates ='drop')

#group by 'balance_buckets' and find average campaign outcome per balance bucket
mean_deposit = df3.groupby(['balance_quantile'])['deposit'].mean()

#plot
plt.plot(mean_deposit.index, mean_deposit.values)
plt.title('Mean % subscription depending on account balance')
plt.xlabel('balance Quantile')
plt.ylabel('Mean probabilty %')
plt.show()

# %%
df3['balance_group'] = pd.qcut(df3['balance'], q=25, precision=0,duplicates ='drop')
mean_deposit = df3.groupby(['balance_group'])['deposit'].mean()
mean_deposit.sort_values(ascending=False).head(10)
# Out:
# balance_group
# (3618.0, 4789.0]    0.216867
# (2189.0, 2801.0]    0.180723
# (1731.0, 2189.0]    0.168675
# (2801.0, 3618.0]    0.162651
# (599.0, 705.0]      0.154762
# (1170.0, 1415.0]    0.150602
# (990.0, 1170.0]     0.138554
# (421.0, 489.0]      0.130178
# (4789.0, 7345.0]    0.126506
# (828.0, 990.0]      0.121212
# Name: deposit, dtype: float64

# %%
for i in range(0,24):
    mean=df3[df3['balance_quantile']==i]['deposit'].mean()
    print(i,"--" ,df3[df3['balance_quantile']==i]['balance_group'].values[0]," Mean prob", mean)
# Out:
# 0 -- (-1.0, 15.0]  Mean prob 0.09018036072144289
# 1 -- (15.0, 49.0]  Mean prob 0.06626506024096386
# 2 -- (49.0, 86.0]  Mean prob 0.08433734939759036
# 3 -- (86.0, 131.0]  Mean prob 0.08433734939759036
# 4 -- (131.0, 179.0]  Mean prob 0.10975609756097561
# 5 -- (179.0, 227.0]  Mean prob 0.09580838323353294
# 6 -- (227.0, 286.0]  Mean prob 0.09523809523809523
# 7 -- (286.0, 348.0]  Mean prob 0.09815950920245399
# 8 -- (348.0, 421.0]  Mean prob 0.07228915662650602
# 9 -- (421.0, 489.0]  Mean prob 0.1301775147928994
# 10 -- (489.0, 599.0]  Mean prob 0.1165644171779141
# 11 -- (599.0, 705.0]  Mean prob 0.15476190476190477
# 12 -- (705.0, 828.0]  Mean prob 0.10975609756097561
# 13 -- (828.0, 990.0]  Mean prob 0.12121212121212122
# 14 -- (990.0, 1170.0]  Mean prob 0.13855421686746988
# 15 -- (1170.0, 1415.0]  Mean prob 0.15060240963855423
# 16 -- (1415.0, 1731.0]  Mean prob 0.11515151515151516
# 17 -- (1731.0, 2189.0]  Mean prob 0.1686746987951807
# 18 -- (2189.0, 2801.0]  Mean prob 0.18072289156626506
# 19 -- (2801.0, 3618.0]  Mean prob 0.16265060240963855
# 20 -- (3618.0, 4789.0]  Mean prob 0.21686746987951808
# 21 -- (4789.0, 7345.0]  Mean prob 0.12650602409638553
# 22 -- (7345.0, 27733.0]  Mean prob 0.08433734939759036
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[141], line 3
#       1 for i in range(0,24):
#       2     mean=df3[df3['balance_quantile']==i]['deposit'].mean()
# ----> 3     print(i,"--" ,df3[df3['balance_quantile']==i]['balance_group'].values[0]," Mean prob", mean)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\_mixins.py:272, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     266 def __getitem__(
#     267     self: NDArrayBackedExtensionArrayT,
#     268     key: PositionalIndexer2D,
#     269 ) -> NDArrayBackedExtensionArrayT | Any:
#     270     if lib.is_integer(key):
#     271         # fast-path
# --> 272         result = self._ndarray[key]
#     273         if self.ndim == 1:
#     274             return self._box_func(result)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
df3['age']=df['age']
df3['age_quantile'] = pd.qcut(df3['age'], q=25, labels=False, duplicates ='drop')

#group by 'age_quantile' and find average campaign outcome per balance bucket
mean_deposit = df3.groupby(['age_quantile'])['deposit'].mean()

#plot
plt.plot(mean_deposit.index, mean_deposit.values)
plt.title('Mean % prob for differents age group')
plt.xlabel('Age Quantile')
plt.ylabel('Mean probabilty %')
plt.show()

# %%
df3['duration']=df['duration']
df3['duration_quantile'] = pd.qcut(df3['duration'], q=25, labels=False, duplicates ='drop')

#group by 'age_quantile' and find average campaign outcome per balance bucket
mean_deposit = df3.groupby(['duration_quantile'])['deposit'].mean()

#plot
plt.plot(mean_deposit.index, mean_deposit.values)
plt.title('Mean % prob for differents Duartion')
plt.xlabel('Duration Quantile')
plt.ylabel('Mean probabilty %')
plt.show()
